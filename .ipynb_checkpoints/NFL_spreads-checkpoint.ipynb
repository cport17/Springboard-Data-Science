# %% [markdown]
# # NFL Spreads
# In this notebook, we will use play by play and per game data from pro-football-reference.com to try to predict how teams will do against the Las Vegas spread.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns
import re

# %% [markdown]
# We have collected four csv files representing the play by play data of the 2014, 2015, 2016, and 2017 seasons in the NFL. We will clean and manipulate this data for our model.

# %%
# get pro-football-reference.com play by play data

df_2014 = pd.read_csv('2014_master.csv')
df_2015 = pd.read_csv('2015_master.csv')
df_2016 = pd.read_csv('2016_master.csv')
df_2017 = pd.read_csv('2017_master.csv')

df_2014['Season'] = 2014
df_2015['Season'] = 2015
df_2016['Season'] = 2016
df_2017['Season'] = 2017

df = pd.concat([df_2014, df_2015, df_2016, df_2017])

# game_type_0 is not a real game type, it is dropped
df = df[df.game_type_0!=1]

# index counter to be removed
df.drop(['Unnamed: 0','game_type_0'], axis=1, inplace=True)

# %%
# rename game_type columns to more readily readable title

new_columns = df.columns.values
new_columns[58:65] = ['TNF', 'Sunday_AM', 'Sunday_PM', 'SNF', 'MNF', 'England', 'Saturday']
df.columns = new_columns

# %%
df.head()
# Out:
#   Away_team  Home_Line  Home_cover Home_team  Season  Week  away_DL_as_total  \
# 0       PIT       -2.5           1       BAL    2014     2          0.041667
# 1       MIA        0.0           1       BUF    2014     2          0.070796
# 2       NOR        6.0           1       CLE    2014     2          0.041667
# 3       DAL       -4.0           0       TEN    2014     2          0.026667
# 4       ARI       -2.0           0       NYG    2014     2          0.000000
#
#    away_DL_compl_perc  away_DL_def_as_total  away_DL_def_comp_perc  \
# 0            0.500000              0.032609               0.333333
# 1            0.000000              0.066667               0.333333
# 2            0.666667              0.033333               0.250000
# 3            0.500000              0.010870               0.000000
# 4            0.000000              0.017857               0.500000
#
#            ...            home_SL_def_as_total  home_SL_def_comp_perc  \
# ...

# %% [markdown]
# Due to the number of columns, we can't use df.info() to quickly see the amount of null values, so we use a for loop to print the amount of nulls in a column.

# %%
for col in df.columns:
    nulls = df[col].isnull().sum()        
    print(col + ' nullls: ' + str(nulls))
# Out:
# Away_team nullls: 0
# Home_Line nullls: 0
# Home_cover nullls: 0
# Home_team nullls: 0
# Season nullls: 0
# Week nullls: 0
# away_DL_as_total nullls: 0
# away_DL_compl_perc nullls: 0
# away_DL_def_as_total nullls: 0
# away_DL_def_comp_perc nullls: 0
# away_DM_as_total nullls: 0
# away_DM_compl_perc nullls: 0
# away_DM_def_as_total nullls: 0
# away_DM_def_comp_perc nullls: 0
# away_DR_as_total nullls: 0
# away_DR_compl_perc nullls: 0
# away_DR_def_as_total nullls: 0
# away_DR_def_comp_perc nullls: 0
# away_LE_as_total nullls: 0
# away_LE_compl_perc nullls: 0
# away_LE_def_as_total nullls: 0
# away_LE_def_comp_perc nullls: 0
# away_LG_as_total nullls: 0
# away_LG_compl_perc nullls: 0
# away_LG_def_as_total nullls: 0
# away_LG_def_comp_perc nullls: 0
# away_LT_as_total nullls: 0
# away_LT_compl_perc nullls: 0
# away_LT_def_as_total nullls: 0
# away_LT_def_comp_perc nullls: 0
# away_M_as_total nullls: 0
# away_M_compl_perc nullls: 0
# away_M_def_as_total nullls: 0
# ...

# %% [markdown]
# There are no nulls. We will just reset the index.

# %%
df.reset_index(drop=True, inplace=True)

# %% [markdown]
# We will take a look at home teams have done against the spread in the past by team and by season. Additionally, we can see how the spread has done in these four seasons overall.

# %%
# Record against the spread

teams = list(df.Home_team.unique())

print('After Week 1 ATS by team past 4 years: ')
for team in teams:
    df_team = df[(df['Home_team']==team) | (df['Away_team']==team)]
    df_team.reset_index(drop=True, inplace=True)
    for year in df['Season'].unique():
        covers = 0
        for game in range(len(df_team)):
            if (df_team.Season[game]==year)&(((df_team.Home_team[game] == team) & (df_team.Home_cover[game] == 1)) | ((df_team.Away_team[game] == team) & (df_team.Home_cover[game] == 0))):
                covers+=1
        print(str(year) + ' ' + team + ' ' + str(covers) + '-' + str(len(df_team[df_team.Season==year])-covers))
        

print('Overall home record against the spread: ' + str(df.Home_cover.sum()) + '-' + str(len(df)-df.Home_cover.sum()) + ' (' + str(df.Home_cover.mean()) + ')')
# Out:
# After Week 1 ATS by team past 4 years:
# 2014 BAL 8-7
# 2015 BAL 6-9
# 2016 BAL 7-8
# 2017 BAL 8-7
# 2014 BUF 8-7
# 2015 BUF 7-8
# 2016 BUF 7-8
# 2017 BUF 8-7
# 2014 CLE 8-7
# 2015 CLE 6-9
# 2016 CLE 5-10
# 2017 CLE 3-12
# 2014 TEN 2-13
# 2015 TEN 5-10
# 2016 TEN 8-7
# 2017 TEN 8-7
# 2014 NYG 7-8
# 2015 NYG 8-7
# 2016 NYG 8-7
# 2017 NYG 7-8
# 2014 CAR 7-8
# 2015 CAR 11-4
# 2016 CAR 6-8
# 2017 CAR 8-7
# 2014 WAS 5-10
# 2015 WAS 9-6
# 2016 WAS 10-5
# 2017 WAS 7-8
# 2014 MIN 8-7
# 2015 MIN 13-2
# 2016 MIN 8-7
# 2017 MIN 12-3
# 2014 CIN 7-8
# 2015 CIN 11-4
# 2016 CIN 6-9
# 2017 CIN 9-6
# 2014 TAM 7-8
# 2015 TAM 7-8
# 2016 TAM 8-7
# 2017 TAM 8-8
# 2014 LAC 6-9
# 2015 LAC 7-8
# 2016 LAC 6-9
# 2017 LAC 9-6
# 2014 OAK 7-8
# 2015 OAK 8-7
# 2016 OAK 9-6
# 2017 OAK 4-11
# 2014 GNB 8-7
# 2015 GNB 6-9
# 2016 GNB 7-8
# 2017 GNB 6-9
# 2014 DEN 8-7
# 2015 DEN 7-8
# 2016 DEN 8-7
# 2017 DEN 4-11
# 2014 SFO 4-11
# 2015 SFO 6-9
# 2016 SFO 4-11
# 2017 SFO 9-6
# 2014 IND 10-5
# 2015 IND 8-7
# ...

# %% [markdown]
# The spread is extremely accurate, as can be seen by the home record against the spread. A percentage so close to 50 means that a team falls on either side of the spread approximately 50 percent of the time.

# %% [markdown]
# Using play by play and rolling average statistics we hope to better the Vegas spreads. First, we create many columns that represent the play by play differences between teams playing each other. We already have each team's data by play type and completion percentage (where completion indicates either a completed pass or a run of 3 yards or more). We then subract the defensive completion percentage of one team from the offensive completion percentage of the other by play type, and the the percentage of total defensive plays by type from the percentage of total offensive plays by type for each team.
#
# Hopefully this data will beat the Vegas spreads by being able to represent how a team that is strong running the ball to the left is better against a team that is weak defending runs to the left for example.

# %%
# create new columns with difference between teams off and defense completion percentage
    
for col in range(66,116,4):
    title = df.columns[col][5:]
    df['home_off_spread_%s' % title] = df[df.columns[col]]-df[df.columns[col-57]]
for col in range(7,59,4):
    title = df.columns[col][5:]
    df['away_off_spread_%s' % title] = df[df.columns[col]]-df[df.columns[col+61]]

# %%
# create new columns with difference between how often offenses run type of play vs how often defenses see type of play
    
for col in range(65,115,4):
    title = df.columns[col][5:]
    df['home_off_spread_%s' % title] = df[df.columns[col]]-df[df.columns[col-57]]
for col in range(6,58,4):
    title = df.columns[col][5:]
    df['away_off_spread_%s' % title] = df[df.columns[col]]-df[df.columns[col+61]]

# %% [markdown]
# We will create another column using the game type columns to represent the days off between games for each team. More days off should mean the team is more prepared for the following game. Vegas likely does take this into account, so it may be represented in the spread. How it will interact with other variables could offer some improvement though.

# %%
df['game_type'] = df[['TNF', 'Sunday_AM', 'Sunday_PM', 'SNF', 'MNF', 'England', 'Saturday']].idxmax(axis=1)

def time_btwn(x):
    week = x[0]
    team = x[1]
    season = x[2]
    game_t = {'TNF':0, 'Sunday_AM':3, 'Sunday_PM':3, 'SNF':3, 'MNF':4, 'England':3, 'Saturday':2}
    try: 
        week_after = df[((df['Week']==week) & (df['Season']==season)) & ((df['Home_team']==team) | (df['Away_team']==team))]['game_type'].iloc[0]
        try:
            week_before = df[((df['Week']==week-1) & (df['Season']==season)) & ((df['Home_team']==team) | (df['Away_team']==team))]['game_type'].iloc[0]
            weekly = 7
        except:
            week_before = df[((df['Week']==week-2) & (df['Season']==season)) & ((df['Home_team']==team) | (df['Away_team']==team))]['game_type'].iloc[0]
            weekly = 14
        tb = game_t[week_after] + weekly - game_t[week_before]
    except:
        tb = 7 
    return tb

df['Home_team_days_after_last_game'] = df[['Week','Home_team','Season']].apply(time_btwn, axis=1)
df['Away_team_days_after_last_game'] = df[['Week','Away_team','Season']].apply(time_btwn, axis=1)

# %% [markdown]
# There was flooding in Tampa and Miami in week 1 of the 2017, as a result their week 2 data has no prior information. Since there is no data for these rows they will be dropped.

# %%
for row in range(len(df[(df['Week']==2) & (df['Season']==2017)])):
    if (df['Home_team'][row]=='MIA') | (df['Home_team'][row]=='TAM') | (df['Away_team'][row]=='MIA') | (df['Away_team'][row]=='TAM'):
        df = df.drop(row)

# %%
df.head()
# Out:
#   Away_team  Home_Line  Home_cover Home_team  Season  Week  away_DL_as_total  \
# 0       PIT       -2.5           1       BAL    2014     2          0.041667
# 2       NOR        6.0           1       CLE    2014     2          0.041667
# 3       DAL       -4.0           0       TEN    2014     2          0.026667
# 4       ARI       -2.0           0       NYG    2014     2          0.000000
# 5       DET       -3.0           1       CAR    2014     2          0.055556
#
#    away_DL_compl_perc  away_DL_def_as_total  away_DL_def_comp_perc  \
# 0            0.500000              0.032609               0.333333
# 2            0.666667              0.033333               0.250000
# 3            0.500000              0.010870               0.000000
# 4            0.000000              0.017857               0.500000
# 5            0.500000              0.011236               1.000000
#
#                 ...                away_off_spread_M_as_total  \
# ...

# %% [markdown]
# Columns indicating the timezones of each team and where the game is played will be made. Generally, it is viewed as harder for a West Coast team to play well in morning games on the East coast because of the time change.

# %%
# join new dummy game types and timezones and drop old game types

df.drop('game_type', axis=1, inplace=True)

# creating teams location features 
# home timezone

def h_tz(x):
    if x in ['LAC','OAK','SEA','LAR','SFO']:
        tz = 'Home_team_west'
    elif x in ['DEN','ARI']:
        tz = 'Home_team_mtn'
    elif x in ['KAN','IND','NOR','DET','MIN','CHI','TEN','GNB','HOU','DAL']:
        tz = 'Home_team_midwest'
    else:
        tz = 'Home_team_east'
    return tz

df['Home_tz'] = df['Home_team'].apply(h_tz)    
        
df = df.join(pd.get_dummies(df['Home_tz']))
df.drop('Home_tz', axis=1, inplace=True)

# away timezone

def a_tz(x):
    if x in ['LAC','OAK','SEA','LAR','SFO']:
        tz = 'Away_team_west'
    elif x in ['DEN','ARI']:
        tz = 'Away_team_mtn'
    elif x in ['KAN','IND','NOR','DET','MIN','CHI','TEN','GNB','HOU','DAL']:
        tz = 'Away_team_midwest'
    else:
        tz = 'Away_team_east'
    return tz

df['Away_tz'] = df['Away_team'].apply(a_tz)  

df = df.join(pd.get_dummies(df['Away_tz']))
df.drop('Away_tz', axis=1, inplace=True)

# game timezone

def g_tz(x):
    if x[1]==1:
        tz = 'game_eng'
    elif x[0] in ['LAC','OAK','SEA','LAR','SFO']:
        tz = 'game_west'
    elif x[0] in ['DEN','ARI']:
        tz = 'game_mtn'
    elif x[0] in ['KAN','IND','NOR','DET','MIN','CHI','TEN','GNB','HOU','DAL']:
        tz = 'game_midwest'
    else:
        tz = 'game_east'
    return tz

df['game_tz'] = df[['Home_team','England']].apply(g_tz, axis=1)  

df = df.join(pd.get_dummies(df['game_tz']))
df.drop('game_tz', axis=1, inplace=True)

# %% [markdown]
# Another column for division games will be made. Division opponents play each other twice a year every year, which may lead to different results than expected.

# %%
# Adding column for division games

def division_game(x):
    AFC_east = ['NWE','BUF','MIA','NYJ']
    AFC_north = ['PIT','BAL','CIN','CLE']
    AFC_south = ['JAX','TEN','IND','HOU']
    AFC_west = ['KAN','LAC','OAK','DEN']
    NFC_east = ['PHI','DAL','WAS','NYG']
    NFC_north = ['MIN','DET','GNB','CHI']
    NFC_south = ['NOR','CAR','ATL','TAM']
    NFC_west = ['LAR','SEA','ARI','SFO']
    home = x[0]
    away = x[1]
    if ((home in AFC_east) & (away in AFC_east)) | ((home in AFC_north) & (away in AFC_north)):
        d = 1
    elif ((home in AFC_south) & (away in AFC_south)) | ((home in AFC_west) & (away in AFC_west)):
        d = 1
    elif ((home in NFC_east) & (away in NFC_east)) | ((home in NFC_north) & (away in NFC_north)):
        d = 1
    elif ((home in NFC_south) & (away in NFC_south)) | ((home in NFC_west) & (away in NFC_west)):
        d = 1
    else:
        d=0
    return d


df['Division_game'] = df[['Home_team','Away_team']].apply(division_game, axis=1)

# %% [markdown]
# Now we will merge our data from the NFL_scrape notebook that has rolling averages for points, yards, and turnovers for and against for each team.

# %%
# import pg and TO numbers

pg = pd.read_csv('NFL_scrape.csv')
pg = pg.drop('Unnamed: 0', axis=1)
df_hw = pd.merge(df, pg, how='left', on=['Week','Season','Home_team','Away_team'])

# %% [markdown]
# We will drop wins in our dataframe that we will use for our models to prevent data leakage.

# %%
df = df_hw.drop('Home_win',axis=1)

# %% [markdown]
# ### Statistical analysis

# %%
df.corr()['Home_cover']
# Out:
# Home_Line                0.001523
# Home_cover               1.000000
# Season                   0.018855
# Week                     0.008145
# away_DL_as_total        -0.041714
# away_DL_compl_perc       0.020589
# away_DL_def_as_total    -0.012906
# away_DL_def_comp_perc   -0.037020
# away_DM_as_total         0.014010
# away_DM_compl_perc      -0.046144
# away_DM_def_as_total     0.092864
# away_DM_def_comp_perc   -0.033997
# away_DR_as_total         0.036091
# away_DR_compl_perc       0.014514
# away_DR_def_as_total    -0.012003
# away_DR_def_comp_perc    0.036430
# away_LE_as_total         0.083217
# away_LE_compl_perc      -0.016047
# away_LE_def_as_total    -0.030476
# away_LE_def_comp_perc   -0.038636
# away_LG_as_total         0.001375
# away_LG_compl_perc      -0.017986
# away_LG_def_as_total    -0.051662
# away_LG_def_comp_perc   -0.034601
# away_LT_as_total        -0.014188
# away_LT_compl_perc      -0.032922
# away_LT_def_as_total    -0.023626
# ...

# %% [markdown]
# As can be seen nothing correlates close to significantly with covering the spread. The spread is well made and accounts for most of these factors. Hopefully combining and using the interaction of these features will lead to a strong model.

# %%
df_hw.corr()['Home_win'][115:]
# Out:
# home_off_spread_DL_compl_perc    0.039644
# home_off_spread_DM_compl_perc    0.004089
# home_off_spread_DR_compl_perc   -0.067129
# home_off_spread_LE_compl_perc    0.081778
# home_off_spread_LG_compl_perc    0.000676
# home_off_spread_LT_compl_perc   -0.016758
# home_off_spread_M_compl_perc     0.025503
# home_off_spread_RE_compl_perc    0.022766
# home_off_spread_RG_compl_perc    0.002472
# home_off_spread_RT_compl_perc   -0.004427
# home_off_spread_SL_compl_perc    0.044780
# home_off_spread_SM_compl_perc    0.033504
# home_off_spread_SR_compl_perc    0.049916
# away_off_spread_DL_compl_perc   -0.015137
# away_off_spread_DM_compl_perc   -0.048437
# away_off_spread_DR_compl_perc    0.049742
# away_off_spread_LE_compl_perc   -0.000862
# away_off_spread_LG_compl_perc    0.020718
# away_off_spread_LT_compl_perc   -0.008549
# away_off_spread_M_compl_perc     0.059833
# away_off_spread_RE_compl_perc   -0.053720
# away_off_spread_RG_compl_perc    0.002615
# ...

# %% [markdown]
# By looking at the correlations by Home_win, we can see that the per game averages represent the likeliest predictors of wins.

# %% [markdown]
# Since the amount of data for a given week increases each week we get deeper into a season, we are going to look at how correlations change by week. I would expect stronger indicators to improve with each week as the data validates its correlation. On the other hand, weaker predictors would likely fluctuate week to week.

# %%
ot = {}

for w in df_hw.Week.unique():
    ot[w]=df_hw[df_hw.Week == w].corr()['Home_win'][-14:-6]
ot_g = pd.DataFrame(ot)

for feat in ot_g.index:
    plt.plot(ot_g.loc[feat])
    plt.xlabel('Week')
    plt.ylabel(feat + ' correlation to wins')
    plt.show()

# %% [markdown]
# All of these correlations bounce around significantly, but some of them trend in certain directions. I would guess these features (such as Away_ypg_for and Away_ppg_for) will more improve our model more than the randomly fluctuating ones (such as Home_ypg_against or Away_ypg_against).

# %% [markdown]
# # Models

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedKFold

# %% [markdown]
# We will have two options for splitting our data. Either leaving out just the 2017 season, or a random split. Splitting by season will lead to an easier representation and interpretation of how a model would have performed, while a random split will give us more data to train with, which would likely help model performance.
#
# For all our models (random forest, logistic regression, and deep learning) the benefits of splitting by season outweigh the costs. Splitting by season will give us a roughly 75-25 train to test split, which is an acceptable amount, and the ability to easily measure performance is critical.
#
# For the deep learning model we will take a different approach to answering this question. We will try to just predict wins, and then see how the model performs when it predicts opposite of the spread.

# %%
# split df by season to test how we would do on 2017 season 

df_test_by_season = df[df['Season']==2017]
df_train_by_season = df[df['Season']!=2017]

y_train = df_train_by_season['Home_cover']
X_train = df_train_by_season.drop(['Season','Home_team', 'Away_team', 'Home_cover'], axis=1)

y_test = df_test_by_season['Home_cover']
X_test = df_test_by_season.drop(['Season','Home_team', 'Away_team', 'Home_cover'], axis=1)

# %% [markdown]
# # Random Forest Model

# %%
params = [{'n_estimators': [7,8,9,10],'max_features': ['auto','sqrt','log2'], 'max_depth':[6,9,10]}]

clf = GridSearchCV(RandomForestClassifier(random_state=42), params, scoring='accuracy', cv=StratifiedKFold(10)).fit(X_train, y_train)
clf.cv_results_
clf.best_params_
print('RFC GridSearchCV Best Score: ', clf.best_score_, ' with ' , clf.best_params_)

print('RFC Test Score: ', accuracy_score(y_test, clf.predict(X_test)))
print('RFC Train Score: ', accuracy_score(y_train, clf.predict(X_train)))
# Out:
# RFC GridSearchCV Best Score:  0.532775453278  with  {'max_depth': 6, 'max_features': 'auto', 'n_estimators': 9}
# RFC Test Score:  0.510373443983
# RFC Train Score:  0.874476987448

# %% [markdown]
# Let's see how our random forest model would have done week by week in the 2017 season based on its five strongest predictions.

# %%
# how model would have done by week in 2017 for top five predictions random forest

# results are in format of (prediction score, actual result, predicted result, home team, the spread, away team)

for week in range(2,18):
    df_test_by_week = df_test_by_season[df_test_by_season['Week']==week]

    y_test_by_week = df_test_by_week['Home_cover']
    X_test_by_week = df_test_by_week.drop(['Season','Home_team', 'Away_team', 'Home_cover'], axis=1)

    guess = list(zip(abs(clf.predict_proba(X_test_by_week)[:,1]-.5), y_test_by_week, [0 if x<.5 else 1 for x in clf.predict_proba(X_test_by_week)[:,1]], df_test_by_week['Home_team'], df_test_by_week['Home_Line'], df_test_by_week['Away_team']))
    top5 = sorted(guess, reverse=True)[:5]
    print(top5)
    w = 0
    for acc in top5:
        if (acc[1]==acc[2]):
            w+=1
    print('Week %d record: ' % week)
    print(str(w) +'-' + str(len(top5)-w))
# Out:
# [(0.30059446726113392, 0, 1, 'CIN', -6.5, 'HOU'), (0.19356794966551061, 1, 1, 'BAL', -8.0, 'CLE'), (0.13556762031432518, 1, 0, 'OAK', -14.0, 'NYJ'), (0.087035421956056847, 0, 0, 'SEA', -14.0, 'SFO'), (0.08161694396634156, 0, 1, 'LAC', -4.0, 'MIA')]
# Week 2 record:
# 2-3
# [(0.24534667881129746, 1, 0, 'WAS', 3.0, 'OAK'), (0.16670008773570699, 1, 1, 'BUF', 3.0, 'DEN'), (0.16131459291985761, 0, 1, 'ARI', 3.0, 'DAL'), (0.14689082323490921, 1, 1, 'MIN', 3.0, 'TAM'), (0.14380143112042909, 0, 1, 'PHI', -6.0, 'NYG')]
# Week 3 record:
# 2-3
# [(0.41342728196023731, 1, 0, 'SEA', -13.0, 'IND'), (0.35853103487512084, 0, 1, 'MIN', -2.5, 'DET'), (0.25566686345964046, 0, 0, 'MIA', 3.0, 'NOR'), (0.19465378790293797, 0, 0, 'BAL', 3.0, 'PIT'), (0.12728999147510217, 1, 0, 'NYJ', 3.5, 'JAX')]
# Week 4 record:
# 2-3
# ...

# %% [markdown]
# Overall, this model would have correctly predicted 43 out of 80 (53.75%) against the spread.
#
# # Logistic Regression Model

# %%
from sklearn.linear_model import LogisticRegression

n_params = [{'penalty':['l1','l2'], 'C':[.01,.1,1,10,100]}]
clf1 = GridSearchCV(LogisticRegression(), n_params, cv=5, scoring='accuracy').fit(X_train, y_train)

print('LR GridSearchCV f1 Score: ', clf1.best_score_, ' with ' , clf1.best_params_ )

print('LR Test Score: ', accuracy_score(y_test, clf1.predict(X_test))) 
print('LR Train Score: ', accuracy_score(y_train, clf1.predict(X_train)))
# Out:
# LR GridSearchCV f1 Score:  0.550906555091  with  {'C': 0.1, 'penalty': 'l1'}
# LR Test Score:  0.547717842324
# LR Train Score:  0.582984658298

# %% [markdown]
# The logistic regression seems to perform better than the random forest. Let's see how it performs on the test season by its five strongest predictions each week.

# %%
# how model would have done by week in 2017 for top five predictions logistic regression

# results are in format of (prediction score, actual result, predicted result, home team, the spread, away team)

for week in range(2,18):
    df_test_by_week = df_test_by_season[df_test_by_season['Week']==week]

    y_test_by_week = df_test_by_week['Home_cover']
    X_test_by_week = df_test_by_week.drop(['Season','Home_team', 'Away_team', 'Home_cover'], axis=1)

    guess = list(zip(abs(clf1.predict_proba(X_test_by_week)[:,1]-.5), y_test_by_week, [0 if x<.5 else 1 for x in clf1.predict_proba(X_test_by_week)[:,1]],df_test_by_week['Home_team'], df_test_by_week['Home_Line'], df_test_by_week['Away_team']))
    top5 = sorted(guess, reverse=True)[:5]
    print(top5)
    w = 0
    for acc in top5:
        if (acc[1]==acc[2]):
            w+=1
    print('Week %d record: ' % week)
    print(str(w) +'-' + str(len(top5)-w))
# Out:
# [(0.25044745931262191, 1, 0, 'TAM', -7.0, 'CHI'), (0.24919982045756295, 1, 0, 'IND', 7.0, 'ARI'), (0.16808312873166553, 0, 1, 'NYG', -3.5, 'DET'), (0.15125279978829087, 0, 0, 'JAX', 2.5, 'TEN'), (0.14512335281560057, 0, 0, 'LAR', -2.5, 'WAS')]
# Week 2 record:
# 2-3
# [(0.15672668473770357, 0, 0, 'CAR', -5.5, 'NOR'), (0.14256633721184331, 1, 1, 'BUF', 3.0, 'DEN'), (0.14009390920786502, 1, 1, 'MIN', 3.0, 'TAM'), (0.12250618052040757, 0, 0, 'PHI', -6.0, 'NYG'), (0.11667052256827271, 1, 0, 'NYJ', 6.0, 'MIA')]
# Week 3 record:
# 4-1
# [(0.1160400397245126, 0, 0, 'ARI', -6.5, 'SFO'), (0.10365839957341888, 0, 0, 'CLE', 3.0, 'CIN'), (0.084025093751007862, 0, 1, 'MIN', -2.5, 'DET'), (0.078229733039024918, 1, 1, 'KAN', -6.5, 'WAS'), (0.073030233179008031, 1, 0, 'HOU', 1.5, 'TEN')]
# Week 4 record:
# 3-2
# ...

# %% [markdown]
# This model would have correctly predicted 45 games out of 80 (56.25%) against the spread. This is definitely superior to the random forest model.

# %% [markdown]
# # Deep Learning Model

# %% [markdown]
# For our deep learning model, we will take a different approach to solving this problem. We will just try to predict who will win each game, then see after the fact how well the model performed when predicting against the spread. This model won't give us a prediction against the spread for every game necessarily. Many times it will agree with the spread, but when it does not agree is when we want to see how it performs. Additionally, a model that predicts winners is useful as well.

# %%
df_test_by_season = df_hw[df_hw['Season']==2017]
df_train_by_season = df_hw[df_hw['Season']!=2017]

y_train = df_train_by_season['Home_win']
X_train = df_train_by_season.drop(['Season','Home_team', 'Away_team', 'Home_win'], axis=1)

y_test = df_test_by_season['Home_win']
X_test = df_test_by_season.drop(['Season','Home_team', 'Away_team', 'Home_win'], axis=1)

# %%
# testing deep learning model

import keras
from keras.layers import Dense, Activation, Dropout
from keras.models import Sequential
from keras.layers.normalization import BatchNormalization
# Out:
# Using TensorFlow backend.

# %%
n_cols = X_train.shape[1]
model = Sequential()
model.add(Dense(200, input_shape = (n_cols,)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(.3))
model.add(Dense(500))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(.3))
model.add(Dense(100))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dense(100))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dense(100))
model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(Dense(1))
model.add(Activation('sigmoid'))

# %%
# Compile the model
adam = keras.optimizers.Adam(lr=0.01, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
model.compile(optimizer=adam, loss='binary_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=100, validation_data=(X_test, y_test), batch_size=8)

adam = keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
model.compile(optimizer=adam, loss='binary_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=50, validation_data=(X_test, y_test), batch_size=8)

adam = keras.optimizers.Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
model.compile(optimizer=adam, loss='binary_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=50, validation_data=(X_test, y_test), batch_size=8)

scores = model.evaluate(X_test, y_test)
print("\n%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# Train on 717 samples, validate on 241 samples
# Epoch 1/100
# 717/717 [==============================] - 2s 2ms/step - loss: 0.7684 - acc: 0.5439 - val_loss: 0.8443 - val_acc: 0.5353
# Epoch 2/100
# 717/717 [==============================] - 1s 749us/step - loss: 0.6958 - acc: 0.5509 - val_loss: 0.6784 - val_acc: 0.6100
# Epoch 3/100
# 717/717 [==============================] - 1s 712us/step - loss: 0.6484 - acc: 0.6388 - val_loss: 1.2648 - val_acc: 0.5726
# Epoch 4/100
# 717/717 [==============================] - 0s 674us/step - loss: 0.6606 - acc: 0.6123 - val_loss: 0.9175 - val_acc: 0.4896
# Epoch 5/100
# 717/717 [==============================] - 0s 655us/step - loss: 0.6369 - acc: 0.6262 - val_loss: 0.6833 - val_acc: 0.6515
# Epoch 6/100
# 717/717 [==============================] - 0s 695us/step - loss: 0.6304 - acc: 0.6569 - val_loss: 1.0011 - val_acc: 0.4689
# Epoch 7/100
# ...

# %%
# by week deep learning

# results are in format of (prediction score, actual result, predicted result, home team, the spread, away team)

o_ats = 0
o_g = 0
for week in range(2,18):
    df_test_by_week = df_hw[(df_hw['Week']==week) & (df_hw['Season']==year)]

    y_week_test = df_test_by_week['Home_win']
    X_week_test = df_test_by_week.drop(['Season','Home_team', 'Away_team', 'Home_win'], axis=1)

    guess = list(zip(abs(model.predict(X_week_test)-.5), y_week_test, [0 if x<.5 else 1 for x in model.predict(X_week_test)], df_test_by_week['Home_team'], df_test_by_week['Home_Line'], df_test_by_week['Away_team'] ))
    top5 = sorted(guess, reverse=True)
    print(top5)
    w = 0
    ats = 0 
    g = 0
    for acc in top5:
        if (acc[1]==acc[2]):
            w+=1
        if ((acc[2]==0)&(acc[4]<0))|((acc[2]==1)&(acc[4]>0))|(acc[4]==0):
            g+=1
            if (acc[1]==acc[2]):
                ats+=1
    o_ats+=ats
    o_g+=g
    print('Week %d record: ' % week)
    print('Wins: ' + str(w) +'-' + str(len(top5)-w) + '\nATS: ' + str(ats) + '-' + str(g-ats))
print('\nOverall ATS: ' + str(o_ats) + '-' + str(o_g-o_ats) + ' (' + str(o_ats/o_g) + '%)')
# Out:
# [(array([ 0.49862635], dtype=float32), 1, 1, 'BAL', -8.0, 'CLE'), (array([ 0.49774432], dtype=float32), 1, 1, 'OAK', -14.0, 'NYJ'), (array([ 0.47991598], dtype=float32), 1, 1, 'SEA', -14.0, 'SFO'), (array([ 0.47383684], dtype=float32), 1, 1, 'TAM', -7.0, 'CHI'), (array([ 0.47089785], dtype=float32), 0, 1, 'CIN', -6.5, 'HOU'), (array([ 0.45901513], dtype=float32), 1, 1, 'KAN', -5.5, 'PHI'), (array([ 0.45409074], dtype=float32), 0, 0, 'JAX', 2.5, 'TEN'), (array([ 0.4515911], dtype=float32), 0, 0, 'LAR', -2.5, 'WAS'), (array([ 0.43908799], dtype=float32), 1, 1, 'ATL', -3.0, 'GNB'), (array([ 0.42596537], dtype=float32), 1, 1, 'DEN', 2.5, 'DAL'), (array([ 0.37995809], dtype=float32), 0, 1, 'IND', 7.0, 'ARI'), (array([ 0.32263863], dtype=float32), 0, 0, 'NOR', 6.5, 'NWE'), (array([ 0.16876942], dtype=float32), 1, 1, 'CAR', -7.0, 'BUF'), (array([ 0.12116462], dtype=float32), 0, 1, 'NYG', -3.5, 'DET'), (array([ 0.10136092], dtype=float32), 1, 1, 'PIT', 0.0, 'MIN'), (array([ 0.03130639], dtyp
# ...

# %% [markdown]
# Interestingly, this model performed much better against the spread than either of the random forest model or the logistic regression model. By picking for wins, instead of wins against the spread, the accuracy on predictions against the spread skyrocketed, from ~55% to ~78%. Although it doesn't make a prediction for every game against the spread, when it picks opposite of the spread (predicting a home win, when the spread indicates an away win, or vice-versa, or a pick'em game (when the spread equals 0)) it is often right.
#
# The results of this model seem to indicate that there is room for improvement in the makings of Vegas's spreads. In the meantime, this model could help someone make some money in Vegas.
